# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Charger le dataset

df = pd.read_csv('Speed Dating Data.csv', encoding= 'unicode_escape')

# %%
# Option pour voir la totalité de nos colonnes

pd.set_option('display.max_column', 195)

# %%
# Visualiser la taille de notre dataset

df.shape
# Out:
# (8378, 195)

# %%
# Aperçu général

df.head(10)
# Out:
#    iid   id  gender  idg  condtn  wave  round  position  positin1  order  \
# 0    1  1.0       0    1       1     1     10         7       NaN      4
# 1    1  1.0       0    1       1     1     10         7       NaN      3
# 2    1  1.0       0    1       1     1     10         7       NaN     10
# 3    1  1.0       0    1       1     1     10         7       NaN      5
# 4    1  1.0       0    1       1     1     10         7       NaN      7
# 5    1  1.0       0    1       1     1     10         7       NaN      6
# 6    1  1.0       0    1       1     1     10         7       NaN      1
# 7    1  1.0       0    1       1     1     10         7       NaN      2
# 8    1  1.0       0    1       1     1     10         7       NaN      8
# 9    1  1.0       0    1       1     1     10         7       NaN      9
#
#    partner   pid  match  int_corr  samerace  age_o  race_o  pf_o_att  \
# 0        1  11.0      0      0.14         0   27.0     2.0     35.00
# ...

# %%
# Observer la répartition de nos features en fonction des types

df.dtypes.value_counts().plot.pie()

# %%
# Aperçu général des valeurs manquantes via une heatmap

sns.heatmap(df.isnull(), cbar=True)
sns.set(rc={'figure.figsize':(20,10)})

# %%
# 1 ère méthode : On supprime les features avec un nombre trop élevé de valeurs manquantes en rentrant le nom de la colonne 

df =  df.drop(columns = ['attr1_s','fun1_s','attr3_s','fun3_s'])

# %%
# 2 nd méthode : On fait du slicing colonnes, en l'occurence les 13 dernières

df  = df.drop(df.columns[-13:], axis=1, inplace=False)

# %%
# On regarde de nouveau la heatmap après une première couche de nettoyage

sns.heatmap(df.isnull(), cbar=True)
sns.set(rc={'figure.figsize':(20,10)})

# %%
# On regarde les features qui présentent un taux trop important de valeurs manquantes 

(df.isna().sum()/df.shape[0]).sort_values(ascending=True)
# Out:
# iid         0.000000
# gender      0.000000
# idg         0.000000
# condtn      0.000000
# wave        0.000000
# round       0.000000
# position    0.000000
# dec         0.000000
# order       0.000000
# partner     0.000000
# match       0.000000
# samerace    0.000000
# dec_o       0.000000
# id          0.000119
# pid         0.001194
# field       0.007520
# race        0.007520
# race_o      0.008713
# tv          0.009429
# imprelig    0.009429
# movies      0.009429
# from        0.009429
# yoga        0.009429
# goal        0.009429
# go_out      0.009429
# shopping    0.009429
# sports      0.009429
# tvsports    0.009429
# dining      0.009429
# museums     0.009429
# theater     0.009429
# art         0.009429
# hiking      0.009429
# gaming      0.009429
# clubbing    0.009429
# imprace     0.009429
# exercise    0.009429
# reading     0.009429
# music       0.009429
# sinc1_1     0.009429
# attr1_1     0.009429
# intel2_1    0.009429
# sinc2_1     0.009429
# ...

# %%
# Vu la taille imposante du dataset on va supprimer toutes les features qui présentent plus de 10% de valeurs manquantes

df = df[df.columns[df.isna().sum()/df.shape[0] < 0.1]]
df.shape

# Il nous reste donc 87 colonnes après ce nettoyage
# Out:
# (8378, 87)

# %%
# On va essayer de relever quelques corrélation malgré le nombre de features encore restant

plt.subplots(figsize=(20,20))

corr = df.corr()
sns.heatmap(corr)

# %%
# On va zoomer sur les qualitées et quelles sont les plus susceptibles de concrétiser un 'match'

df1 = pd.concat([df['match'],df['attr'],df['sinc'],df['intel'],df['fun'],df['amb'],
                   df['like'],df['prob'],df['met']],axis=1)
plt.subplots(figsize=(15,10))
ax = plt.axes()
ax.set_title("Heatmap n° 1")
corr = df1.corr()
sns.heatmap(corr, 
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values)

# Fun et like semblent avoir une bonne corrélation avec le match
# On voit également une forte corrélation entre certaines qualités

# %%
# On appercoit une deuxième zone fortement corrélé qui correspond aux activités

df2 = pd.concat([df['match'],df['sports'],df['tvsports'],df['exercise'],df['dining'],df['museums'],
                   df['art'],df['hiking'],df['gaming'],df['reading'],df['tv'],df['theater'],
                    df['movies'],df['concerts'],df['music'],df['shopping'],df['yoga']],axis=1)
plt.subplots(figsize=(15,10))
ax = plt.axes()
ax.set_title("Heatmap n° 2")
corr = df2.corr()
sns.heatmap(corr, 
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values)

# On ne voit pas de corréalation flagrante entre les activités et les 'matchs' 
# Néanmoins on voit clairement des 'pairs' (dining/shopping ou tv/shopping)

# %%
# Préparation d'un nouveau dataset sans les features explorées

df3 = df.drop(columns = ['match','attr','sinc','intel','fun','amb',
                   'like','prob','met','match','sports','tvsports','exercise','dining','museums',
                   'art','hiking','gaming','reading','tv','theater',
                    'movies','concerts','music','shopping','yoga'])

# %%
# Nouvelle heatmap 

corr = df3.corr()
sns.heatmap(corr, 
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values)

# %%
# Nous allons explorer les domaines d'études des prétendants
# Pour cela nous allons associer chaque nombre au domaine d'étude auquel il correspond

df['field_cd'] = df.field_cd.map({1: 'Law', 2: 'Math', 3: 'Soc. Sc.', 4: 'Med. Sc.', 5: 'Eng.', 6: 'Journ.',
                                  7: 'Hist.', 8: 'Econ', 9: 'Educ.',10: 'Nat. Sc.', 11: 'Soc. Wr.', 12: 'Und.',
                                  13: 'Pol. Sc.', 14: 'Film', 15: 'Arts', 16:'Lang.', 17: 'Arch.', 18: 'Oth.'}).fillna(df.field_cd)
# Out:
# C:\Anaconda\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# Représentation graphique entre le nombre de prétendants et leur domaine d'étude respectif

plt.figure(figsize = (16,6))
ax = sns.countplot(x="field_cd", data=df)
plt.title("Domaine d'étude", fontsize=14)

ax.set_xticklabels(ax.get_xticklabels(),rotation=40)

plt.ylim(0, 2000)
plt.xlabel('')
plt.ylabel('Nombre')
# Out:
# Text(0, 0.5, 'Nombre')

# %%
# Nous pouvons également regarder le rapport en fonction du genre 

# Nous remplaçons 0-1 par Femme-Homme pour une meilleure compréhension

df['gender'] = df['gender'].astype(str) 
df['gender'] = df['gender'].replace(str(0), 'Femme')
df['gender'] = df['gender'].replace(str(1), 'Homme')

# Représentation graphique

mf = df[['gender', 'field_cd']].groupby(['field_cd', 'gender']).size().unstack()
ax = mf.plot(kind='bar', figsize=(16,6), stacked=True)
ax.set_xticklabels(ax.get_xticklabels(), fontsize=12, rotation=45)

ax.set_title("Domaine d'étude par genre", fontsize=14)
ax.set_xlabel('')
ax.set_ylabel('Nombre')
# Out:
# C:\Anaconda\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# C:\Anaconda\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Anaconda\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
# Cette analyse nous a permis de voir quelles features a de l'importance 
# La prochaine étape sera de faire le preprocessing pour ensuite procèder à la mise en place de modèle de ML
